# %% [markdown]
# # Project 6. Rossman store sales forecasting
# The goal of the **[competition](https://www.kaggle.com/competitions/rossmann-store-sales/overview)** is to forecast the store sales 6 weeks into the future - a very concrete objective - whilst essentially a regression tasks, due to the length of the prediction time target, it will definitely require a more careful approach, accounting for time-related transformations / characteristics of the data such as trends, seasonality and other factors, which might or might not be present in the data, influencing the historical, datetimed datapoints.
#
# The specified measurement target of choice is the **Root Mean Square Percentage Error (RMSPE)**
#
# Non-obvious columns/factors:
# * Customers - the number of customers on a given day
# * StateHoliday - indicates a state holiday. Normally all stores, with few exceptions, are closed on state holidays. Note that all schools are closed on public holidays and weekends. a = public holiday, b = Easter holiday, c = Christmas, 0 = None
# * SchoolHoliday - indicates if the (Store, Date) was affected by the closure of public schools
# * StoreType - differentiates between 4 different store models: a, b, c, d
# * Assortment - describes an assortment level: a = basic, b = extra, c = extended
# * CompetitionDistance - distance in meters to the nearest competitor store
# * CompetitionOpenSince(Month/Year) - gives the approximate year and month of the time the nearest competitor was opened
# * Promo - indicates whether a store is running a promo on that day
# * Promo2 - Promo2 is a continuing and consecutive promotion for some stores: 0 = store is not participating, 1 = store is participating
# * PromoInterval - describes the consecutive intervals Promo2 is started, naming the months the promotion is started anew. E.g. "Feb,May,Aug,Nov" means each round starts in February, May, August, November of any given year for that store
#
# The supplied data is split across multiple files for train data, test data (which can only be evaluated by submitting the prediction on it to the competition site) and data about stores, unrelated to time points.
#
# For the purpose of a separate testing set, we will reserve a portion of the dataset ourselves to test the resultant models finetuned on train and validation data splits.

# %% [markdown]
# ## Code setup

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow import keras
from tensorflow.keras import layers
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from sklearn.linear_model import LinearRegression

# regplot equations etc
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
df_path = '../datasets/rossmann/train.csv'
df = pd.read_csv(df_path, index_col=0)

store_path = '../datasets/rossmann/store.csv'
store_df = pd.read_csv(store_path)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_23660\2426903770.py:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(df_path, index_col=0)

# %% [markdown]
# ### Reversing the ordering of the train dataset
# with cells commented out for safe notebook runs

# %%
df['Date'].max()
# Out:
# '2015-07-31'

# %%
df['Date'].min()
# Out:
# '2013-01-01'

# %%
df.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
df.tail()
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 1017204   1111          2  2013-01-01      0          0     0      0
# 1017205   1112          2  2013-01-01      0          0     0      0
# 1017206   1113          2  2013-01-01      0          0     0      0
# 1017207   1114          2  2013-01-01      0          0     0      0
# 1017208   1115          2  2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday
# 1017204            a              1
# 1017205            a              1
# 1017206            a              1
# 1017207            a              1
# 1017208            a              1

# %%
df_sorted = df.sort_values(by=['Date', 'Store'], ascending=True).reset_index(drop=True)

# %%
df_sorted.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          2  2013-01-01      0          0     0      0            a
# 1      2          2  2013-01-01      0          0     0      0            a
# 2      3          2  2013-01-01      0          0     0      0            a
# 3      4          2  2013-01-01      0          0     0      0            a
# 4      5          2  2013-01-01      0          0     0      0            a
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
# df_sorted.to_csv(df_path)

# %% [markdown]
# ## EDA, inspecting the data

# %%
df.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          2  2013-01-01      0          0     0      0            a
# 1      2          2  2013-01-01      0          0     0      0            a
# 2      3          2  2013-01-01      0          0     0      0            a
# 3      4          2  2013-01-01      0          0     0      0            a
# 4      5          2  2013-01-01      0          0     0      0            a
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
store_df.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# ...

# %%
df.shape
# Out:
# (1017209, 9)

# %%
store_df.shape
# Out:
# (1115, 10)

# %%
df.dtypes
# Out:
# Store             int64
# DayOfWeek         int64
# Date             object
# Sales             int64
# Customers         int64
# Open              int64
# Promo             int64
# StateHoliday     object
# SchoolHoliday     int64
# dtype: object

# %%
df.nunique()
# Out:
# Store             1115
# DayOfWeek            7
# Date               942
# Sales            21734
# Customers         4086
# Open                 2
# Promo                2
# StateHoliday         5
# SchoolHoliday        2
# dtype: int64

# %%
df['StateHoliday'].unique()
# Out:
# array(['a', '0', 'b', 'c', 0], dtype=object)

# %% [markdown]
# #### 'Date' column to datetime format

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.dtypes
# Out:
# Store                     int64
# DayOfWeek                 int64
# Date             datetime64[ns]
# Sales                     int64
# Customers                 int64
# Open                      int64
# Promo                     int64
# StateHoliday             object
# SchoolHoliday             int64
# dtype: object

# %% [markdown]
# ### Dataframe with means for every store, grouped by date

# %%
means_df = df.groupby(by=['Date'], as_index=False)[['Sales', 'Customers', 'Open', 'Promo']].mean()

# %%
means_df
# Out:
#           Date        Sales   Customers      Open  Promo
# 0   2013-01-01    87.284560   17.496409  0.015260    0.0
# 1   2013-01-02  6233.030493  748.049327  0.996413    0.0
# 2   2013-01-03  5693.112108  682.547085  0.994619    0.0
# 3   2013-01-04  5954.218834  701.468161  0.993722    0.0
# 4   2013-01-05  5337.751570  616.566816  0.992825    0.0
# ..         ...          ...         ...       ...    ...
# 937 2015-07-27  9602.952466  870.369507  0.998206    1.0
# 938 2015-07-28  8174.953363  785.732735  0.998206    1.0
# 939 2015-07-29  7623.284305  743.070852  0.998206    1.0
# 940 2015-07-30  7891.348879  769.997309  0.998206    1.0
# 941 2015-07-31  9067.033184  868.717489  0.998206    1.0
#
# [942 rows x 5 columns]

# %%
plt.figure(figsize=(15,8))
ax = sns.regplot(data=means_df, x=means_df.index, y='Sales')
ax.set_title("Average sales over time")
# Out:
# Text(0.5, 1.0, 'Average sales over time')

# %%
plt.figure(figsize=(15,8))
ax = sns.regplot(data=means_df, x=means_df.index, y='Customers')
ax.set_title("Average customers over time")
# Out:
# Text(0.5, 1.0, 'Average customers over time')

# %% [markdown]
# #### How about on singular stores?

# %%
store_33_df = df[df['Store'] == 33].groupby(by=['Date'], as_index=False)[['Sales', 'Customers', 'Open', 'Promo']].mean()
store_114_df = df[df['Store'] == 114].groupby(by=['Date'], as_index=False)[['Sales', 'Customers', 'Open', 'Promo']].mean()
store_256_df = df[df['Store'] == 256].groupby(by=['Date'], as_index=False)[['Sales', 'Customers', 'Open', 'Promo']].mean()

# %%
plt.figure(figsize=(15,8))
ax = sns.regplot(data=store_33_df, x=store_33_df.index, y='Sales')
ax = sns.regplot(data=store_114_df, x=store_33_df.index, y='Sales')
ax = sns.regplot(data=store_256_df, x=store_33_df.index, y='Sales')
plt.legend(['33', '114', '256'])
ax.set_title("Average sales over time for random store (33 , 114 and 256)")
# Out:
# Text(0.5, 1.0, 'Average sales over time for random store (33 , 114 and 256)')

# %% [markdown]
# Okay, the days with 0 sales (probably holidays or weekends) are really throwing the trends off, let's try to exclude them for a quick look

# %%
no_zero_33 = store_33_df[store_33_df['Sales'] > 0]
plt.figure(figsize=(15,8))
ax = sns.regplot(data=no_zero_33, x=no_zero_33.index, y='Sales')
ax.set_title("Store 33 no 0 sales")
# Out:
# Text(0.5, 1.0, 'Store 33 no 0 sales')

# %% [markdown]
# ### Lag, lead, time step, futher singular store or all stores exploration

# %%
store_42_df = df[df['Store'] == 42].reset_index()

# %% [markdown]
# Time feature

# %%
store_42_df['Time'] = np.arange(len(store_42_df.index))

# %%
store_42_df['Lag_1'] = store_42_df['Sales'].shift(1)

# %%
store_42_df.head()
# Out:
#    index  Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 0     41     42          2 2013-01-01      0          0     0      0
# 1   1155     42          3 2013-01-02   7959       1046     1      0
# 2   2270     42          4 2013-01-03   6925        896     1      0
# 3   3385     42          5 2013-01-04   8273        940     1      0
# 4   4500     42          6 2013-01-05   7587        905     1      0
#
#   StateHoliday  SchoolHoliday  Time   Lag_1
# 0            a              1     0     NaN
# 1            0              1     1     0.0
# 2            0              1     2  7959.0
# 3            0              1     3  6925.0
# 4            0              0     4  8273.0

# %%
fig, ax = plt.subplots()
ax = sns.regplot(data=store_42_df, x='Lag_1', y='Sales')
ax.set_aspect('equal')
ax.set_title('Lag plot')
# Out:
# Text(0.5, 1.0, 'Lag plot')

# %%
fig, ax = plt.subplots()
ax = sns.regplot(data=store_42_df[(store_42_df['Sales'] > 0) & (store_42_df['Lag_1'] > 0)], x='Lag_1', y='Sales')
ax.set_aspect('equal')
ax.set_title('Lag plot with sales > 0 of store 42 (random)')
# Out:
# Text(0.5, 1.0, 'Lag plot with sales > 0 of store 42 (random)')

# %% [markdown]
# Clearly, there is a possibility of serial dependence for some stores, as seen by the gradual increase of sales

# %% [markdown]
# Can a similar trend be seen for the average of the stores, whilst exluding the days with no sales (weekend, holidays) for a clearer picture

# %%
means_df_nonzero = df[df['Sales']>0].groupby(by=['Date'], as_index=False)[['Sales', 'Customers',
                                                                           'Open', 'Promo']].mean()

# %%
means_df_nonzero['Lag_1'] = means_df_nonzero['Sales'].shift(1)

# %%
fig, ax = plt.subplots()
ax = sns.regplot(data=means_df_nonzero, x='Lag_1', y='Sales')
ax.set_aspect('equal')
ax.set_title('Lag plot with sales > 0 of all stores')
# Out:
# Text(0.5, 1.0, 'Lag plot with sales > 0 of all stores')

# %% [markdown]
# ### Test linear models with '0' sales excluded

# %%
X = means_df_nonzero['Lag_1'].fillna(0).values
Y = means_df_nonzero['Sales'].values
X = sm.add_constant(X)
sales_lag_model = sm.OLS(Y, X)
# sales_lag_model = smf.ols(formula = 'Lag_1 ~ Sales', data=means_df_nonzero)
results = sales_lag_model.fit()
results.params
# Out:
# array([4.17534092e+03, 4.24995568e-01])

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.184
# Model:                            OLS   Adj. R-squared:                  0.183
# Method:                 Least Squares   F-statistic:                     211.5
# Date:                Tue, 12 Mar 2024   Prob (F-statistic):           2.28e-43
# Time:                        19:10:24   Log-Likelihood:                -8280.0
# No. Observations:                 942   AIC:                         1.656e+04
# Df Residuals:                     940   BIC:                         1.657e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4175.3409    217.966     19.156      0.000    3747.584    4603.098
# ...

# %%
model_lin_means = LinearRegression()
model_lin_means.fit(X, Y)
y_pred = pd.Series(model_lin_means.predict(X))

# %%
fig, ax = plt.subplots()
sns.lineplot(data=means_df_nonzero, x='Lag_1', y='Sales', ax=ax)
sns.lineplot(x=means_df_nonzero['Lag_1'], y=y_pred, ax=ax)
# ax.set_aspect('equal')
ax.set_title('Model with predictions')
# Out:
# Text(0.5, 1.0, 'Model with predictions')

# %% [markdown]
# ### Averaged stores trend / moving average

# %%
moving_average = means_df_nonzero['Sales'].rolling(
    window = 14, # 2 week window
    center = True, # puts the average at the center of the window
    min_periods = 7, # about half the window size
).mean()

# %%
ax = means_df_nonzero['Sales'].plot(style='.', color='0.5')
moving_average.plot(
    ax = ax, linewidth = 3, title = 'Sales 2-week moving average', legend=False,
);

# %%
moving_average = means_df_nonzero['Sales'].rolling(
    window = 31, # 2 week window
    center = True, # puts the average at the center of the window
    min_periods = 15, # about half the window size
).mean()

ax = means_df_nonzero['Sales'].plot(style='.', color='0.5')
moving_average.plot(
    ax = ax, linewidth = 3, title = 'Sales monthly moving average', legend=False,
);

# %% [markdown]
# ## Seasonality and Fourier Transforms
# from [Kaggle](https://www.kaggle.com/code/ryanholbrook/seasonality)

# %%
from statsmodels.tsa.deterministic import CalendarFourier, DeterministicProcess

# simplefilter("ignore")

# Set Matplotlib defaults
# plt.style.use("seaborn-whitegrid")
plt.rc("figure", autolayout=True, figsize=(11, 5))
plt.rc(
    "axes",
    labelweight="bold",
    labelsize="large",
    titleweight="bold",
    titlesize=16,
    titlepad=10,
)
plot_params = dict(
    color="0.75",
    style=".-",
    markeredgecolor="0.25",
    markerfacecolor="0.25",
    legend=False,
)
# %config InlineBackend.figure_format = 'retina'


# annotations: https://stackoverflow.com/a/49238256/5769929
def seasonal_plot(X, y, period, freq, ax=None):
    if ax is None:
        _, ax = plt.subplots()
    palette = sns.color_palette("husl", n_colors=X[period].nunique(),)
    ax = sns.lineplot(
        x=freq,
        y=y,
        hue=period,
        data=X,
        ci=False,
        ax=ax,
        palette=palette,
        legend=False,
    )
    ax.set_title(f"Seasonal Plot ({period}/{freq})")
    for line, name in zip(ax.lines, X[period].unique()):
        y_ = line.get_ydata()[-1]
        ax.annotate(
            name,
            xy=(1, y_),
            xytext=(6, 0),
            color=line.get_color(),
            xycoords=ax.get_yaxis_transform(),
            textcoords="offset points",
            size=14,
            va="center",
        )
    return ax


def plot_periodogram(ts, detrend='linear', ax=None):
    from scipy.signal import periodogram
    fs = pd.Timedelta("365D") / pd.Timedelta("1D")
    freqencies, spectrum = periodogram(
        ts,
        fs=fs,
        detrend=detrend,
        window="boxcar",
        scaling='spectrum',
    )
    if ax is None:
        _, ax = plt.subplots()
    ax.step(freqencies, spectrum, color="purple")
    ax.set_xscale("log")
    ax.set_xticks([1, 2, 4, 6, 12, 26, 52, 104])
    ax.set_xticklabels(
        [
            "Annual (1)",
            "Semiannual (2)",
            "Quarterly (4)",
            "Bimonthly (6)",
            "Monthly (12)",
            "Biweekly (26)",
            "Weekly (52)",
            "Semiweekly (104)",
        ],
        rotation=30,
    )
    ax.ticklabel_format(axis="y", style="sci", scilimits=(0, 0))
    ax.set_ylabel("Variance")
    ax.set_title("Periodogram")
    return ax

# %%
X = means_df_nonzero.copy()

# %%
X['day'] = X['Date'].dt.dayofweek
X['week'] = X['Date'].dt.isocalendar().week
X['dayofyear'] = X['Date'].dt.dayofyear
X['year'] = X['Date'].dt.year
X['month'] = X['Date'].dt.month

# %%
fig, (ax0, ax1, ax2) = plt.subplots(3, 1, figsize=(11, 9))
seasonal_plot(X, y="Sales", period="week", freq="day", ax=ax0)
seasonal_plot(X, y="Sales", period="year", freq="dayofyear", ax=ax1);
seasonal_plot(X, y="Sales", period="year", freq="month", ax=ax2);
# seasonal_plot(X, y="Sales", period="year", freq="dayofyear", ax=ax3);
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_23660\3547315223.py:31: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   ax = sns.lineplot(
# C:\Users\User\AppData\Local\Temp\ipykernel_23660\3547315223.py:31: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   ax = sns.lineplot(
# C:\Users\User\AppData\Local\Temp\ipykernel_23660\3547315223.py:31: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   ax = sns.lineplot(

# %%
plot_periodogram(X.Sales);

# %% [markdown]
# Predicting with a yearly fourrier something?

# %%
from statsmodels.tsa.deterministic import CalendarFourier, DeterministicProcess

fourier = CalendarFourier(freq="YE", order=10)  # 10 sin/cos pairs for "A"nnual seasonality

dp = DeterministicProcess(
    index=X.Date,
    constant=True,               # dummy feature for bias (y-intercept)
    order=1,                     # trend (order 1 means linear)
    seasonal=True,               # weekly seasonality (indicators)
    additional_terms=[fourier],  # annual seasonality (fourier)
    drop=True,                   # drop terms to avoid collinearity
)

X = dp.in_sample()  # create features for dates in tunnel.index

# %%
y = means_df_nonzero["Sales"]

model = LinearRegression(fit_intercept=False)
_ = model.fit(X, y)

y_pred = pd.Series(model.predict(X), index=means_df_nonzero.Date)
X_fore = dp.out_of_sample(steps=90)
y_fore = pd.Series(model.predict(X_fore), index=X_fore.index)

ax = y.plot(color='0.25', style='.', title="Sales - Seasonal Forecast")
ax = y_pred.plot(ax=ax, label="Seasonal")
ax = y_fore.plot(ax=ax, label="Seasonal Forecast", color='C3')
_ = ax.legend()
# Out:
# C:\Users\User\Desktop\programowanie_web_etc\python_projects\ml_zoo\venv\lib\site-packages\statsmodels\tsa\deterministic.py:307: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# C:\Users\User\Desktop\programowanie_web_etc\python_projects\ml_zoo\venv\lib\site-packages\statsmodels\tsa\deterministic.py:440: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# ...

# %% [markdown]
# ## TODO:
# https://www.kaggle.com/code/maciejmarkowski/exercise-seasonality/edit
